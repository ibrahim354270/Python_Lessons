# %% [markdown]
# # Comparison Operators

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
5 == 5
# Out:
# True

# %%
9 == 2
# Out:
# False

# %%
0 != 0
# Out:
# False

# %%
1 != 3
# Out:
# True

# %%
2 != 2
# Out:
# False

# %%
2 > 3
# Out:
# False

# %%
2 > 1
# Out:
# True

# %%
3 < 4
# Out:
# True

# %%
3 <= 4
# Out:
# True

# %%
2 <= 2
# Out:
# True

# %%
4 >= 5
# Out:
# False

# %%
0 != 0
# Out:
# False

# %%
0 is not False
# Out:
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /var/folders/gc/dgrq1wb15vj3d0ks8rg135nm0000gn/T/ipykernel_96217/1166683470.py:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   0 is not False
# True

# %% [markdown]
# # Logical Operators

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### not / is not

# %% [markdown]
# is not operatörü nesnelerin kimliklerini (adreslerini) karşılaştırırken, != operatörü değerlerin eşitliğini kontrol eder.
#
# 0 is not False True döndürür çünkü 0 ve False farklı nesneler (kimlikler) olsa da mantıksal olarak birbirine eşdeğerdir.
#
# 0 != 0 ise False döner çünkü değerler aynıdır.

# %%
not 1   # not önüne geldiği ifadenin tersini (True ise False; False ise True döndürür.)
# Out:
# False

# %%
not False
# Out:
# True

# %%
not 0
# Out:
# True

# %%
1 is not False   # Comparison
# Out:
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /var/folders/gc/dgrq1wb15vj3d0ks8rg135nm0000gn/T/ipykernel_96217/3181265007.py:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   1 is not False
# True

# %%
1 != False
# Out:
# True

# %%
0 is not False
# Out:
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /var/folders/gc/dgrq1wb15vj3d0ks8rg135nm0000gn/T/ipykernel_96217/1166683470.py:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   0 is not False
# True

# %% [markdown]
# ### and

# %%
2 and 3  # Hepsi True olduğunda en sonuncuyu yazdırır.
# Out:
# 3

# %%
0 and 4  # Gördüğü ilk False değeri yazdırır.
# Out:
# 0

# %%
1 and False and 0 and 5
# Out:
# False

# %% [markdown]
# ### or

# %%
0 or 1   # İlk gördüğü True ifadeyi döndürür.
# Out:
# 1

# %%
None or 5 or 0 or 1
# Out:
# 5

# %%
# Hepsi False ise sonuncuyu döndürür.
0 or False or None  # None döndürdü

# %%
None or 0
# Out:
# 0

# %%
2 or 0 or 9  # İlk gördüğü True ifadeyi döndürür
# Out:
# 2

# %%
"Bilsen" or [] and 0
# Out:
# 'Bilsen'

# %%
False or 9 and not 0
# Out:
# True

# %%
[] or not 1 and 0
# Out:
# False

# %%
True or False and not 0 and 8 or False
# Out:
# True

# %%
not 0
# Out:
# True

# %%
not 1
# Out:
# False

# %%
'Mukaddes' or []
# Out:
# 'Mukaddes'

# %%
'To be' or not 'To be'
# Out:
# 'To be'

# %% [markdown]
# ## input()

# %%
input("Adınızı yazınız.")
# Out:
# 'canan'

# %%
input("Yaşınızı yazınız")  # input() metodu çıktısı str olur.
# Out:
# '90'

# %%
isim = input("Adınızı yazınız.")

# %%
isim
# Out:
# 'Bilsen'

# %%
yas = input("Bir sayı giriniz.")

# %%
yas
# Out:
# '45'

# %%
type(yas)
# Out:
# str

# %%
# 10 yıl sonra kaç yaşında olacak?
yas_10 = yas + 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 2
#       1 # 10 yıl sonra kaç yaşında olacak?
# ----> 2 yas_10 = yas + 10
#
# TypeError: can only concatenate str (not "int") to str

# %%
# 10 yıl sonra kaç yaşında olacak?
yas_10 = int(yas) + 10
print(f"Bugünkü yaşınız {yas}, 10 yıl sonra {yas_10} yaşında olacaksınız.") # f string metodu ile değişkenleri string içerisinde kullanabiliyoruz.
# Out:
# Bugünkü yaşınız 45, 10 yıl sonra 55 yaşında olacaksınız.

# %%
# Girilen sayının karesini hesaplayın?
sayi = input("Bir sayı giriniz.")
sayi = int(sayi)
karesi = sayi ** 2
print(f"Girdiğinz sayı {sayi}. Bu sayının karesi {karesi}")
# Out:
# Girdiğinz sayı 5. Bu sayının karesi 25

# %%
sayi_1 = float(input("Numara giriniz."))
type(sayi_1)
# Out:
# float

# %%
sayi_1
# Out:
# 6.0

# %%
yas_1 = int(input("Yaşınızı yazınız."))
print(f"Yaşınız {yas_1}, on yıl sonra {yas_1 + 10} yaşında olacaksınız.")
# Out:
# Yaşınız 15, on yıl sonra 25 yaşında olacaksınız.

# %%
print (f "{yas_1}") # f-string metodunda f ve tırnak işareti arasında boşluk bırakılmamalı.
# Out:
#   Cell In[58], line 1
#     print (f "{yas_1}")
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## lower()

# %%
isim = "Miyase"
print(isim)
print(isim.lower())
# Out:
# Miyase
# miyase

# %%
x = "TECHPRO Education"
x.lower()
# Out:
# 'techpro education'

# %%
sehir = input("Yaşadığınız şehir")
sehir
# Out:
# 'ANTALYA'

# %%
sehir_1 = input("Yaşadığınız şehir").lower()  # String ifadeleri küçük harfe dönüştürür
sehir_1
# Out:
# 'konya'

# %% [markdown]
# ## upper()

# %%
sehir_2 = input("Bir şehir giriniz")
print(sehir_2)
print(sehir_2.upper())
print(sehir_2.lower())
# Out:
# Van
# VAN
# van

# %%
"İZMİR".lower()
# Out:
# 'i̇zmi̇r'

# %%
"izmir".upper()   # String ifadeleri büyük harfe dönüştürür
# Out:
# 'IZMIR'

# %% [markdown]
# ## title()

# %%
"istanbul".title()  # Her bir sözcüğün ilk harfini büyük harf yapar
# Out:
# 'Istanbul'

# %%
"birazdan mola vereceğiz.".title()
# Out:
# 'Birazdan Mola Vereceğiz.'

# %% [markdown]
# ## capitalize()

# %%
"python öğrenmek çok eğlenceli:)".capitalize() # Cümlenin ilk harfini büyük harf yapar.
# Out:
# 'Python öğrenmek çok eğlenceli:)'

# %%
"python öğrenmek çok eğlenceli:)".title()
# Out:
# 'Python Öğrenmek Çok Eğlenceli:)'

# %% [markdown]
# ## swapcase()

# %%
"pyTHON".swapcase() # Büyük harfleri küçük küçük harfleri de büyük yapar.
# Out:
# 'PYthon'

# %%
"Techpro Education".swapcase()
# Out:
# 'tECHPRO eDUCATION'

# %% [markdown]
# ## Indexing and Slicing

# %%
name = "Techpro Education"
print(f"Hello, my name is {name}.")
# Out:
# Hello, my name is Techpro Education.

# %%
name[0]
# Out:
# 'T'

# %%
name[8]
# Out:
# 'E'

# %%
name[7]
# Out:
# ' '

# %%
name[-1]
# Out:
# 'n'

# %%
name[-5]
# Out:
# 'a'

# %%
name
# Out:
# 'Techpro Education'

# %%
name[12]
# Out:
# 'a'

# %%
name[16]
# Out:
# 'n'

# %%
name[-(-3)]
# Out:
# 'h'

# %%
"Techpro" + " " + "Education" # + string ifadelrle kullanılınca uç uca ekleme yani concat. yapar.
# Out:
# 'Techpro Education'

# %%
"techpro" - "pro"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 "techpro" - "pro"
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
"techpro" * 3  # * string ifadeleri verilen sayı kadar uç uca ekler.
# Out:
# 'techprotechprotechpro'

# %%
name
# Out:
# 'Techpro Education'

# %%
name[4] + name[5] + name[6]
# Out:
# 'pro'

# %%
name[2] + name[-5] + name[-1]
# Out:
# 'can'

# %%
name[2] + name[-5] + name[-1] + name[-5] + name[-1]
# Out:
# 'canan'

# %%
name[4:7]  # değişken[start : stop] start dahildir stop indexi dahil değildir.
# Out:
# 'pro'

# %%
name[:4]
# Out:
# 'Tech'

# %%
name[-5:2]
# Out:
# ''

# %%
name[::-1]
# Out:
# 'noitacudE orphceT'

# %% [markdown]
# Techpro Education

# %%
name[-2:-5:-1]  #Python her zaman soldan sağa çalışır.
# Out:
# 'oit'

# %%
name[-2::-5]   # değişken[start : stop : step] step negatif girilirse tersten okur.
# Out:
# 'ourT'

# %%
name[-2:2]
# Out:
# ''

# %%
name[3:-5:2]
# Out:
# 'hr dc'

# %%
name_1 = name[3:7]
name_1
# Out:
# 'hpro'

# %% [markdown]
# ## len()

# %%
name
# Out:
# 'Techpro Education'

# %%
len(name) # string ifadedeki eleman sayısını verir. İndex sayısından bir fazladır, 0'dan başlamaz.
# Out:
# 17

# %%
len("Gülay")
# Out:
# 5

# %%
"Gülay"[:3]
# Out:
# 'Gül'

# %% [markdown]
# ## replace()

# %%
name
# Out:
# 'Techpro Education'

# %%
name.replace(" ", "&")
# Out:
# 'Techpro&Education'

# %%
name_2 = "Dersimiz Bitiyor"
print(name_2)
print(name_2.replace("i", "$"))  #verilen alt dizeyi yeni ifade ile değiştirir.
# Out:
# Dersimiz Bitiyor
# Ders$m$z B$t$yor
